# %% [markdown]
# # ALeRCE classes
#
# https://github.com/ZwickyTransientFacility/ztf-avro-alert
#
# 1. **AGN:** Active Galactic Nuclei
# 1. **Blazar:** Blazar
# 1. **CV/Nova:** Cataclysmic Variable Star/Nova
# 1. **Ceph:** Cepheid Variable Star
# 1. **DSCT:** Delta Scuti Star
# 1. **EA:** Eclipsing Algol
# 1. **EB/EW:** Eclipsing Binaries/Eclipsing W Ursa Majoris
# 1. **LPV:** Long Period Variable
# 1. **Periodic-Other:** Periodic-Other
# 1. **QSO:** Quasi-Stellar Object
# 1. **RRL:** RRLyrae Variable Star
# 1. **RSCVn:** RS Canum Venaticorum
# 1. **SLSN:** Super Luminous Supernova
# 1. **SNII:** Supernova II
# 1. **SNIIb:** Supernova IIb
# 1. **SNIIn:** Supernova IIn
# 1. **SNIa:** Supernova Ia
# 1. **SNIbc:** Supernova Ibc
# 1. **TDE:** Tidal disruption event (to remove)
# 1. **YSO:** Young Stellar Object
# 1. **ZZ:** ZZ Ceti Stars (to remove)

# %% [markdown]
# # Columns names
# 1. **oid:** object id
# 1. **classALeRCE:** object class name
# 1. **fid:** band index, g=1, r=2

# %%
import sys
sys.path.append('../')
sys.path.append('../../')

# %%
import numpy as np
import pandas as pd

#survey_name = 'alerceZTFv5.1'
survey_name = 'alerceZTFv7.1' # use this dataset
df_index_names = {
    'oid':'oid', # object id
    'label':'classALeRCE', # object class name
    'ra':'ra',
    'dec':'dec',
    'band':'fid', # band
    'obs_day':'mjd', # days
    'obs':'magpsf_corr', # observations
    'obs_error':'sigmapsf_corr', # observation errors
}

### load files
load_root_dir = f'../data/{survey_name}'
labels_df = pd.read_parquet(f'{load_root_dir}/labels.parquet')
print(f'labels_df - columns: {list(labels_df.columns)} - id: {labels_df.index.name}')

features_train_df = pd.read_parquet(f'{load_root_dir}/features_train.parquet')
print(f'features_train_df - id: {features_train_df.index.name}')
for k,c in enumerate(list(features_train_df.columns)):
    print(f'({k}) - {c}')

features_test_df = pd.read_parquet(f'{load_root_dir}/features_test.parquet')
#print(f'features_test_df - columns: {list(features_test_df.columns)} - id: {features_test_df.index.name}')
# Out:
# labels_df - columns: ['classALeRCE', 'ra', 'dec', 'period', 'source', 'id_source', 'class_source', 'separation_arcsec'] - id: oid
# features_train_df - id: oid
# (0) - Amplitude_1
# (1) - Amplitude_2
# (2) - AndersonDarling_1
# (3) - AndersonDarling_2
# (4) - Autocor_length_1
# (5) - Autocor_length_2
# (6) - Beyond1Std_1
# (7) - Beyond1Std_2
# (8) - Con_1
# (9) - Con_2
# (10) - Eta_e_1
# (11) - Eta_e_2
# (12) - ExcessVar_1
# (13) - ExcessVar_2
# (14) - GP_DRW_sigma_1
# (15) - GP_DRW_sigma_2
# (16) - GP_DRW_tau_1
# (17) - GP_DRW_tau_2
# (18) - Gskew_1
# (19) - Gskew_2
# (20) - Harmonics_mag_1_1
# (21) - Harmonics_mag_1_2
# (22) - Harmonics_mag_2_1
# (23) - Harmonics_mag_2_2
# (24) - Harmonics_mag_3_1
# (25) - Harmonics_mag_3_2
# (26) - Harmonics_mag_4_1
# (27) - Harmonics_mag_4_2
# (28) - Harmonics_mag_5_1
# (29) - Harmonics_mag_5_2
# (30) - Harmonics_mag_6_1
# (31) - Harmonics_mag_6_2
# (32) - Harmonics_mag_7_1
# (33) - Harmonics_mag_7_2
# (34) - Harmonics_mse_1
# (35) - Harmonics_mse_2
# (36) - Harmonics_phase_2_1
# (37) - Harmonics_phase_2_2
# (38) - Harmonics_phase_3_1
# (39) - Harmonics_phase_3_2
# (40) - Harmonics_phase_4_1
# (41) - Harmonics_phase_4_2
# (42) - Harmonics_phase_5_1
# (43) - Harmonics_phase_5_2
# (44) - Harmonics_phase_6_1
# (45) - Harmonics_phase_6_2
# (46) - Harmonics_phase_7_1
# (47) - Harmonics_phase_7_2
# (48) - IAR_phi_1
# (49) - IAR_phi_2
# (50) - LinearTrend_1
# (51) - LinearTrend_2
# (52) - MHPS_PN_flag_1
# (53) - MHPS_PN_flag_2
# (54) - MHPS_high_1
# (55) - MHPS_high_2
# (56) - MHPS_low_1
# (57) - MHPS_low_2
# (58) - MHPS_non_zero_1
# (59) - MHPS_non_zero_2
# (60) - MHPS_ratio_1
# (61) - MHPS_ratio_2
# (62) - MaxSlope_1
# (63) - MaxSlope_2
# (64) - Mean_1
# (65) - Mean_2
# (66) - Meanvariance_1
# (67) - Meanvariance_2
# (68) - MedianAbsDev_1
# (69) - MedianAbsDev_2
# (70) - MedianBRP_1
# (71) - MedianBRP_2
# (72) - Multiband_period
# (73) - PairSlopeTrend_1
# (74) - PairSlopeTrend_2
# (75) - PercentAmplitude_1
# (76) - PercentAmplitude_2
# (77) - Period_band_1
# (78) - Period_band_2
# (79) - Period_fit
# (80) - Power_rate_1/2
# (81) - Power_rate_1/3
# (82) - Power_rate_1/4
# (83) - Power_rate_2
# (84) - Power_rate_3
# (85) - Power_rate_4
# (86) - Psi_CS_1
# (87) - Psi_CS_2
# (88) - Psi_eta_1
# (89) - Psi_eta_2
# (90) - Pvar_1
# (91) - Pvar_2
# (92) - Q31_1
# (93) - Q31_2
# (94) - Rcs_1
# (95) - Rcs_2
# (96) - SF_ML_amplitude_1
# (97) - SF_ML_amplitude_2
# (98) - SF_ML_gamma_1
# (99) - SF_ML_gamma_2
# (100) - SPM_A_1
# (101) - SPM_A_2
# (102) - SPM_beta_1
# (103) - SPM_beta_2
# (104) - SPM_chi_1
# (105) - SPM_chi_2
# (106) - SPM_gamma_1
# (107) - SPM_gamma_2
# (108) - SPM_t0_1
# (109) - SPM_t0_2
# (110) - SPM_tau_fall_1
# (111) - SPM_tau_fall_2
# (112) - SPM_tau_rise_1
# (113) - SPM_tau_rise_2
# (114) - Skew_1
# (115) - Skew_2
# (116) - SmallKurtosis_1
# (117) - SmallKurtosis_2
# (118) - Std_1
# (119) - Std_2
# (120) - StetsonK_1
# (121) - StetsonK_2
# (122) - delta_mag_fid_1
# (123) - delta_mag_fid_2
# (124) - delta_mjd_fid_1
# (125) - delta_mjd_fid_2
# (126) - delta_period_1
# (127) - delta_period_2
# (128) - dmag_first_det_fid_1
# (129) - dmag_first_det_fid_2
# (130) - dmag_non_det_fid_1
# (131) - dmag_non_det_fid_2
# (132) - first_mag_1
# (133) - first_mag_2
# (134) - g-r_max
# (135) - g-r_max_corr
# (136) - g-r_mean
# (137) - g-r_mean_corr
# (138) - gal_b
# (139) - gal_l
# (140) - iqr_1
# (141) - iqr_2
# (142) - last_diffmaglim_before_fid_1
# (143) - last_diffmaglim_before_fid_2
# (144) - last_mjd_before_fid_1
# (145) - last_mjd_before_fid_2
# (146) - max_diffmaglim_after_fid_1
# (147) - max_diffmaglim_after_fid_2
# (148) - max_diffmaglim_before_fid_1
# (149) - max_diffmaglim_before_fid_2
# (150) - mean_mag_1
# (151) - mean_mag_2
# (152) - median_diffmaglim_after_fid_1
# (153) - median_diffmaglim_after_fid_2
# (154) - median_diffmaglim_before_fid_1
# (155) - median_diffmaglim_before_fid_2
# (156) - min_mag_1
# (157) - min_mag_2
# (158) - n_det_1
# (159) - n_det_2
# (160) - n_neg_1
# (161) - n_neg_2
# (162) - n_non_det_after_fid_1
# (163) - n_non_det_after_fid_2
# (164) - n_non_det_before_fid_1
# (165) - n_non_det_before_fid_2
# (166) - n_pos_1
# (167) - n_pos_2
# (168) - positive_fraction_1
# (169) - positive_fraction_2
# (170) - rb
# (171) - sgscore1

# %%
print(labels_df.info())
labels_df[:20]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118469 entries, ZTF19abmposz to ZTF18abgqxlw
# Data columns (total 8 columns):
# classALeRCE          118469 non-null object
# ra                   118469 non-null float32
# dec                  118469 non-null float32
# period               66253 non-null object
# source               118469 non-null object
# id_source            118469 non-null object
# class_source         118469 non-null object
# separation_arcsec    118469 non-null float32
# dtypes: float32(3), object(5)
# memory usage: 6.8+ MB
# None
#              classALeRCE          ra        dec period  source  \
# oid
# ZTF19abmposz         AGN   26.670031  -8.354787   None  Oh2015
# ZTF19aapcxhy         AGN  154.202133  18.723076   None  Oh2015
# ZTF18abtyspw         AGN   25.660297   0.087434   None  Oh2015
# ZTF18aaodoxr         AGN  208.231995  25.483231   None  Oh2015
# ZTF18acidtzj         AGN  173.724503  22.452370   None  Oh2015
# ZTF18aaqdpre         AGN  172.851654  34.503368   None  Oh2015
# ZTF18aawqdsi         AGN  172.457413  37.281502   None  Oh2015
# ZTF19aaoznlm         AGN  196.137634   3.299838   None  Oh2015
# ZTF19aauiwtc         AGN  199.213776   5.946401   None  Oh2015
# ZTF19aapvkcg         AGN  184.594666  38.845402   None  Oh2015
# ZTF18aarlyfl         AGN  182.635742  41.674965   None  Oh2015
# ZTF19aatvmnb         AGN  330.094360  11.921089   None  Oh2015
# ZTF18aavljow         AGN  255.507584  36.366074   None  Oh2015
# ZTF19aagflki         AGN  234.274796   0.923011   None  Oh2015
# ZTF19abdkehs         AGN   19.871077  -0.144355   None  Oh2015
# ZTF18abetdjv         AGN  245.631195  22.027235   None  Oh2015
# ZTF19aapwgnn         AGN  237.460602  30.852945   None  Oh2015
# ZTF18acxhmdi         AGN  343.271271  14.064254   None  Oh2015
# ZTF18abdrhon         AGN  224.578720  19.990099   None  Oh2015
# ZTF19aasexgn         AGN  204.096146  25.538715   None  Oh2015
#
#                           id_source          class_source  separation_arcsec
# oid
# ZTF19abmposz  5.877271806085038e+17  AGN_galaxy_dominated           0.213990
# ZTF19aapcxhy  5.877420127343739e+17  AGN_galaxy_dominated           0.227455
# ZTF18abtyspw  5.880155092805878e+17  AGN_galaxy_dominated           0.141792
# ZTF18aaodoxr  5.877398104846501e+17  AGN_galaxy_dominated           0.100498
# ZTF18acidtzj  5.877420143531131e+17  AGN_galaxy_dominated           0.354353
# ZTF18aaqdpre  5.877394073146492e+17  AGN_galaxy_dominated           0.201170
# ZTF18aawqdsi  5.877386175635128e+17  AGN_galaxy_dominated           0.078565
# ZTF19aaoznlm  5.877260338661951e+17  AGN_galaxy_dominated           0.141731
# ZTF19aauiwtc  5.877291605789902e+17  AGN_galaxy_dominated           0.316322
# ZTF19aapvkcg  5.880179772823306e+17  AGN_galaxy_dominated           0.048622
# ZTF18aarlyfl  5.880177201074012e+17  AGN_galaxy_dominated           0.044509
# ZTF19aatvmnb   5.87727221400732e+17  AGN_galaxy_dominated           0.221486
# ZTF18aavljow  5.880070052724082e+17  AGN_galaxy_dominated           0.054373
# ZTF19aagflki  5.877297468397322e+17  AGN_galaxy_dominated           0.064793
# ZTF19abdkehs  5.877315126062612e+17  AGN_galaxy_dominated           0.107311
# ZTF18abetdjv  5.880179783797966e+17  AGN_galaxy_dominated           0.362704
# ZTF19aapwgnn  5.877368984988552e+17  AGN_galaxy_dominated           0.155988
# ZTF18acxhmdi  5.877307744185224e+17  AGN_galaxy_dominated           0.336376
# ZTF18abdrhon  5.877398453863055e+17  AGN_galaxy_dominated           0.082391
# ZTF19aasexgn  5.877416009658533e+17  AGN_galaxy_dominated           0.396914

# %%
print(features_train_df.info())
features_train_df[:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118469 entries, ZTF17aaabgdt to ZTF20abfpkfh
# Columns: 172 entries, Amplitude_1 to sgscore1
# dtypes: float32(172)
# memory usage: 83.6+ MB
# None
#               Amplitude_1  Amplitude_2  AndersonDarling_1  AndersonDarling_2  \
# oid
# ZTF17aaabgdt     0.164834          NaN           0.762395                NaN
# ZTF17aaadfsa     0.196974     0.185956           1.000000           1.000000
# ZTF17aaadxdb     0.253045     0.349630           1.000000           1.000000
# ZTF17aaadzlq     2.482923     1.983951           1.000000           1.000000
# ZTF17aaaenfy     0.487668     0.455345           1.000000           1.000000
# ZTF17aaagrhs     0.466147     0.295652           1.000000           1.000000
# ZTF17aaagvzo     0.450122     0.347737           1.000000           1.000000
# ZTF17aaagwfr     0.481463     0.448709           1.000000           1.000000
# ZTF17aaahtas     0.192741     0.105586           1.000000           0.981686
# ZTF17aaaiogt     0.242838     0.166340           1.000000           0.999619
#
#               Autocor_length_1  Autocor_length_2  Beyond1Std_1  Beyond1Std_2  \
# oid
# ZTF17aaabgdt               1.0               NaN      0.285714           NaN
# ZTF17aaadfsa               2.0               1.0      0.405405      0.470588
# ZTF17aaadxdb               1.0               1.0      0.500000      0.350000
# ZTF17aaadzlq              13.0              14.0      0.531646      0.469925
# ZTF17aaaenfy               1.0               1.0      0.344444      0.318182
# ZTF17aaagrhs               1.0               1.0      0.331461      0.481781
# ZTF17aaagvzo               1.0               1.0      0.480769      0.326087
# ZTF17aaagwfr               1.0               1.0      0.400000      0.368421
# ZTF17aaahtas               1.0               1.0      0.428571      0.357143
# ZTF17aaaiogt               1.0               1.0      0.312500      0.272727
#
#                  Con_1     Con_2  ...  n_non_det_after_fid_1  \
# oid                               ...
# ZTF17aaabgdt  0.000000       NaN  ...                   10.0
# ZTF17aaadfsa  0.000000  0.000000  ...                   33.0
# ZTF17aaadxdb  0.000000  0.000000  ...                   72.0
# ZTF17aaadzlq  0.038298  0.049242  ...                   35.0
# ZTF17aaaenfy  0.000000  0.000000  ...                   99.0
# ZTF17aaagrhs  0.000000  0.000000  ...                  239.0
# ZTF17aaagvzo  0.000000  0.000000  ...                   21.0
# ZTF17aaagwfr  0.000000  0.000000  ...                   26.0
# ZTF17aaahtas  0.000000  0.000000  ...                   25.0
# ZTF17aaaiogt  0.000000  0.000000  ...                   14.0
#
#               n_non_det_after_fid_2  n_non_det_before_fid_1  \
# oid
# ZTF17aaabgdt                    NaN                     0.0
# ZTF17aaadfsa                   63.0                     0.0
# ZTF17aaadxdb                  106.0                     0.0
# ZTF17aaadzlq                   30.0                     0.0
# ZTF17aaaenfy                   90.0                     1.0
# ZTF17aaagrhs                  288.0                     0.0
# ZTF17aaagvzo                   57.0                     0.0
# ZTF17aaagwfr                   46.0                     2.0
# ZTF17aaahtas                   38.0                     9.0
# ZTF17aaaiogt                   17.0                     0.0
#
#               n_non_det_before_fid_2  n_pos_1  n_pos_2  positive_fraction_1  \
# oid
# ZTF17aaabgdt                     NaN      3.0      NaN             0.428571
# ZTF17aaadfsa                     0.0     15.0     17.0             0.405405
# ZTF17aaadxdb                     0.0     27.0     17.0             0.385714
# ZTF17aaadzlq                     0.0     35.0     25.0             0.147679
# ZTF17aaaenfy                     0.0     52.0     53.0             0.577778
# ZTF17aaagrhs                     0.0    151.0     61.0             0.424157
# ZTF17aaagvzo                     1.0     18.0     35.0             0.346154
# ZTF17aaagwfr                     3.0     11.0     20.0             0.440000
# ZTF17aaahtas                     1.0     15.0      0.0             0.535714
# ZTF17aaaiogt                     0.0     11.0      7.0             0.687500
#
#               positive_fraction_2        rb  sgscore1
# oid
# ZTF17aaabgdt                  NaN  0.874286  0.942000
# ZTF17aaadfsa             0.500000  0.822857  0.990833
# ZTF17aaadxdb             0.425000  0.731429  0.973417
# ZTF17aaadzlq             0.093985  0.828571  0.939375
# ZTF17aaaenfy             0.481818  0.905714  1.000000
# ZTF17aaagrhs             0.246964  0.778571  0.999000
# ZTF17aaagvzo             0.760870  0.915000  0.994583
# ZTF17aaagwfr             0.526316  0.820000  1.000000
# ZTF17aaahtas             0.000000  0.882857  0.979917
# ZTF17aaaiogt             0.636364  0.788571  0.994375
#
# [10 rows x 172 columns]

# %%
print(features_test_df.info())
features_test_df[:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 779846 entries, ZTF17aaaafan to ZTF20abpvghz
# Columns: 172 entries, Amplitude_1 to sgscore1
# dtypes: float32(172)
# memory usage: 517.6+ MB
# None
#               Amplitude_1  Amplitude_2  AndersonDarling_1  AndersonDarling_2  \
# oid
# ZTF17aaaafan     0.094794     0.269390           0.500701           0.997029
# ZTF17aaaafbs     0.399396     0.368885           1.000000           1.000000
# ZTF17aaabdlz     0.151955     0.143481           1.000000           1.000000
# ZTF17aaabelc     0.247272     0.114171           1.000000           0.481141
# ZTF17aaabmro     0.530131     0.334390           1.000000           1.000000
# ZTF17aaacvqh     0.208042     0.192441           1.000000           1.000000
# ZTF17aaadina     1.004704     1.046327           0.818453           0.894374
# ZTF17aaadkeg     0.203057     0.424995           0.325656           1.000000
# ZTF17aaadotj     0.282452     0.239367           1.000000           1.000000
# ZTF17aaadskg     0.490247     0.393771           1.000000           1.000000
#
#               Autocor_length_1  Autocor_length_2  Beyond1Std_1  Beyond1Std_2  \
# oid
# ZTF17aaaafan               2.0               1.0      0.285714      0.571429
# ZTF17aaaafbs               1.0               1.0      0.294118      0.308824
# ZTF17aaabdlz               1.0               1.0      0.214286      0.409091
# ZTF17aaabelc               1.0               2.0      0.272727      0.400000
# ZTF17aaabmro               1.0               1.0      0.352941      0.366667
# ZTF17aaacvqh               1.0               1.0      0.523810      0.370968
# ZTF17aaadina               1.0               1.0      0.230769      0.240000
# ZTF17aaadkeg               1.0               2.0      0.300000      0.415094
# ZTF17aaadotj               1.0               1.0      0.387097      0.407407
# ZTF17aaadskg               1.0               1.0      0.383562      0.333333
#
#               Con_1     Con_2  ...  n_non_det_after_fid_1  \
# oid                            ...
# ZTF17aaaafan    0.0  0.000000  ...                  179.0
# ZTF17aaaafbs    0.0  0.000000  ...                  134.0
# ZTF17aaabdlz    0.0  0.000000  ...                   86.0
# ZTF17aaabelc    0.0  0.000000  ...                   76.0
# ZTF17aaabmro    0.0  0.000000  ...                   29.0
# ZTF17aaacvqh    0.0  0.000000  ...                   88.0
# ZTF17aaadina    0.0  0.000000  ...                   14.0
# ZTF17aaadkeg    0.0  0.039216  ...                  257.0
# ZTF17aaadotj    0.0  0.000000  ...                   34.0
# ZTF17aaadskg    0.0  0.000000  ...                   35.0
#
#               n_non_det_after_fid_2  n_non_det_before_fid_1  \
# oid
# ZTF17aaaafan                  151.0                     6.0
# ZTF17aaaafbs                  117.0                     7.0
# ZTF17aaabdlz                   88.0                     1.0
# ZTF17aaabelc                  103.0                     3.0
# ZTF17aaabmro                   32.0                     5.0
# ZTF17aaacvqh                   60.0                     0.0
# ZTF17aaadina                   27.0                     0.0
# ZTF17aaadkeg                  208.0                     3.0
# ZTF17aaadotj                   40.0                     1.0
# ZTF17aaadskg                   65.0                     0.0
#
#               n_non_det_before_fid_2  n_pos_1  n_pos_2  positive_fraction_1  \
# oid
# ZTF17aaaafan                    11.0      0.0      3.0             0.000000
# ZTF17aaaafbs                     1.0     36.0     38.0             0.705882
# ZTF17aaabdlz                     0.0     11.0     13.0             0.785714
# ZTF17aaabelc                    14.0     16.0      0.0             0.727273
# ZTF17aaabmro                     0.0      4.0     19.0             0.235294
# ZTF17aaacvqh                     2.0      7.0     33.0             0.166667
# ZTF17aaadina                     0.0     14.0     14.0             0.538462
# ZTF17aaadkeg                     2.0      0.0      8.0             0.000000
# ZTF17aaadotj                     1.0     11.0     15.0             0.354839
# ZTF17aaadskg                     1.0     19.0     37.0             0.260274
#
#               positive_fraction_2        rb  sgscore1
# oid
# ZTF17aaaafan             0.428571  0.644286  0.984375
# ZTF17aaaafbs             0.558824  0.764286  0.986917
# ZTF17aaabdlz             0.590909  0.720714  0.977125
# ZTF17aaabelc             0.000000  0.851190  1.000000
# ZTF17aaabmro             0.633333  0.931429  0.998750
# ZTF17aaacvqh             0.532258  0.792143  0.966208
# ZTF17aaadina             0.560000  0.793333  0.983125
# ZTF17aaadkeg             0.150943  0.787143  0.924417
# ZTF17aaadotj             0.555556  0.811429  0.987262
# ZTF17aaadskg             0.822222  0.917857  1.000000
#
# [10 rows x 172 columns]

# %%
# %load_ext autoreload
# %autoreload 2
from mismatch import C_
from mismatch.utils import get_object_features
from dask import dataframe as dd

### example using dask
features_train_ddf = dd.from_pandas(features_train_df, npartitions=C_.N_DASK) # dask dataframe can be faster
features_test_ddf = dd.from_pandas(features_test_df, npartitions=C_.N_DASK) # dask dataframe can be faster
labels_ddf = dd.from_pandas(labels_df, npartitions=C_.N_DASK) # dask dataframe can be faster
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### get all features from an object
obj_name = 'ZTF18abvpirg' # from train
features, c, features_names = get_object_features(features_train_ddf, labels_ddf, obj_name)
fdict = {f:features[kf] for kf,f in enumerate(features_names)}
print(f'obj: {obj_name} - class: {c} - features: {len(features)}')
for k,key in enumerate(fdict.keys()):
    print(f'({k}) - {key}: {fdict[key]}')
# Out:
# obj: ZTF18abvpirg - class: Ceph - features: 172
# (0) - Amplitude_1: 1.0310996770858765
# (1) - Amplitude_2: 0.7456786632537842
# (2) - AndersonDarling_1: 0.9999358654022217
# (3) - AndersonDarling_2: 0.9988798499107361
# (4) - Autocor_length_1: 4.0
# (5) - Autocor_length_2: 4.0
# (6) - Beyond1Std_1: 0.3461538553237915
# (7) - Beyond1Std_2: 0.3478260934352875
# (8) - Con_1: 0.0
# (9) - Con_2: 0.0
# (10) - Eta_e_1: 0.010806181468069553
# (11) - Eta_e_2: 0.003990760073065758
# (12) - ExcessVar_1: 0.0012663761153817177
# (13) - ExcessVar_2: 0.0009696251363493502
# (14) - GP_DRW_sigma_1: 0.20221443474292755
# (15) - GP_DRW_sigma_2: 0.19696539640426636
# (16) - GP_DRW_tau_1: 60.67272186279297
# (17) - GP_DRW_tau_2: 76.49195098876953
# (18) - Gskew_1: 0.21646809577941895
# (19) - Gskew_2: 0.03816690668463707
# (20) - Harmonics_mag_1_1: 0.6572859883308411
# (21) - Harmonics_mag_1_2: 0.5342311263084412
# (22) - Harmonics_mag_2_1: 0.06727560609579086
# (23) - Harmonics_mag_2_2: 0.09318407624959946
# (24) - Harmonics_mag_3_1: 0.1119856908917427
# (25) - Harmonics_mag_3_2: 0.07179965078830719
# (26) - Harmonics_mag_4_1: 0.12274118512868881
# (27) - Harmonics_mag_4_2: 0.05941290035843849
# (28) - Harmonics_mag_5_1: 0.057103462517261505
# (29) - Harmonics_mag_5_2: 0.022104410454630852
# (30) - Harmonics_mag_6_1: 0.06308390200138092
# (31) - Harmonics_mag_6_2: 0.01652875542640686
# (32) - Harmonics_mag_7_1: 0.005024974700063467
# (33) - Harmonics_mag_7_2: 0.08856547623872757
# (34) - Harmonics_mse_1: 0.0406515970826149
# (35) - Harmonics_mse_2: 0.03449799492955208
# (36) - Harmonics_phase_2_1: 2.0009756088256836
# (37) - Harmonics_phase_2_2: 0.8639952540397644
# (38) - Harmonics_phase_3_1: 6.043892860412598
# (39) - Harmonics_phase_3_2: 2.563486099243164
# (40) - Harmonics_phase_4_1: 6.1681036949157715
# (41) - Harmonics_phase_4_2: 1.4631379842758179
# (42) - Harmonics_phase_5_1: 1.801235556602478
# (43) - Harmonics_phase_5_2: 1.900222659111023
# (44) - Harmonics_phase_6_1: 2.4778904914855957
# (45) - Harmonics_phase_6_2: 2.7093186378479004
# (46) - Harmonics_phase_7_1: 0.04875669628381729
# (47) - Harmonics_phase_7_2: 2.673715591430664
# (48) - IAR_phi_1: 0.991150438785553
# (49) - IAR_phi_2: 0.9900448322296143
# (50) - LinearTrend_1: 0.0013732707593590021
# (51) - LinearTrend_2: 0.0014667846262454987
# (52) - MHPS_PN_flag_1: 0.0
# (53) - MHPS_PN_flag_2: 0.0
# (54) - MHPS_high_1: 0.007308231666684151
# (55) - MHPS_high_2: 0.005496296565979719
# (56) - MHPS_low_1: 11.7152738571167
# (57) - MHPS_low_2: 6.736705780029297
# (58) - MHPS_non_zero_1: 42.0
# (59) - MHPS_non_zero_2: 37.0
# (60) - MHPS_ratio_1: 1603.0242919921875
# (61) - MHPS_ratio_2: 1225.680908203125
# (62) - MaxSlope_1: 0.6155768036842346
# (63) - MaxSlope_2: 0.9420113563537598
# (64) - Mean_1: 17.454833984375
# (65) - Mean_2: 16.067943572998047
# (66) - Meanvariance_1: 0.035897184163331985
# (67) - Meanvariance_2: 0.03120652586221695
# (68) - MedianAbsDev_1: 0.5407611727714539
# (69) - MedianAbsDev_2: 0.48488378524780273
# (70) - MedianBRP_1: 0.2884615361690521
# (71) - MedianBRP_2: 0.239130437374115
# (72) - Multiband_period: 120.48186492919922
# (73) - PairSlopeTrend_1: 0.10000000149011612
# (74) - PairSlopeTrend_2: 0.10000000149011612
# (75) - PercentAmplitude_1: 0.06758933514356613
# (76) - PercentAmplitude_2: 0.059900037944316864
# (77) - Period_band_1: 120.48186492919922
# (78) - Period_band_2: 120.48186492919922
# (79) - Period_fit: 0.14047516882419586
# (80) - Power_rate_1/2: 0.017695672810077667
# (81) - Power_rate_1/3: 0.010019431822001934
# (82) - Power_rate_1/4: 0.00591428903862834
# (83) - Power_rate_2: 0.008055132813751698
# (84) - Power_rate_3: 0.0020129734184592962
# (85) - Power_rate_4: 0.008709192276000977
# (86) - Psi_CS_1: 0.345560222864151
# (87) - Psi_CS_2: 0.35889336466789246
# (88) - Psi_eta_1: 0.20559142529964447
# (89) - Psi_eta_2: 0.31520551443099976
# (90) - Pvar_1: 1.0
# (91) - Pvar_2: 1.0
# (92) - Q31_1: 1.1266120672225952
# (93) - Q31_2: 0.8810051679611206
# (94) - Rcs_1: 0.345560222864151
# (95) - Rcs_2: 0.3384127616882324
# (96) - SF_ML_amplitude_1: 1.3339520692825317
# (97) - SF_ML_amplitude_2: 1.0273281335830688
# (98) - SF_ML_gamma_1: 0.4822067320346832
# (99) - SF_ML_gamma_2: 0.3204360604286194
# (100) - SPM_A_1: 0.44269534945487976
# (101) - SPM_A_2: 2.0593111515045166
# (102) - SPM_beta_1: 0.15157769620418549
# (103) - SPM_beta_2: 0.1524869054555893
# (104) - SPM_chi_1: 56.96652603149414
# (105) - SPM_chi_2: 216.07359313964844
# (106) - SPM_gamma_1: 85.20677185058594
# (107) - SPM_gamma_2: 100.0
# (108) - SPM_t0_1: 48.18293762207031
# (109) - SPM_t0_2: 34.54386901855469
# (110) - SPM_tau_fall_1: 99.99945831298828
# (111) - SPM_tau_fall_2: 90.0054931640625
# (112) - SPM_tau_rise_1: 70.36084747314453
# (113) - SPM_tau_rise_2: 61.77204513549805
# (114) - Skew_1: 0.16314253211021423
# (115) - Skew_2: 0.08840081840753555
# (116) - SmallKurtosis_1: -0.9578419923782349
# (117) - SmallKurtosis_2: -1.1066428422927856
# (118) - Std_1: 0.6265794634819031
# (119) - Std_2: 0.5014247298240662
# (120) - StetsonK_1: 0.9490160942077637
# (121) - StetsonK_2: 0.9495806097984314
# (122) - delta_mag_fid_1: 2.127901077270508
# (123) - delta_mag_fid_2: 1.765496850013733
# (124) - delta_mjd_fid_1: 733.063720703125
# (125) - delta_mjd_fid_2: 631.1726684570312
# (126) - delta_period_1: 0.0
# (127) - delta_period_2: 0.0
# (128) - dmag_first_det_fid_1: nan
# (129) - dmag_first_det_fid_2: 3.731934070587158
# (130) - dmag_non_det_fid_1: nan
# (131) - dmag_non_det_fid_2: 4.391388893127441
# (132) - first_mag_1: 17.47696304321289
# (133) - first_mag_2: 16.014366149902344
# (134) - g-r_max: 1.3278560638427734
# (135) - g-r_max_corr: 1.2227473258972168
# (136) - g-r_mean: 1.164468765258789
# (137) - g-r_mean_corr: 1.3868906497955322
# (138) - gal_b: -63.463775634765625
# (139) - gal_l: 70.93750762939453
# (140) - iqr_1: 1.1266120672225952
# (141) - iqr_2: 0.8810051679611206
# (142) - last_diffmaglim_before_fid_1: nan
# (143) - last_diffmaglim_before_fid_2: 19.746299743652344
# (144) - last_mjd_before_fid_1: nan
# (145) - last_mjd_before_fid_2: 58456.1484375
# (146) - max_diffmaglim_after_fid_1: 20.399099349975586
# (147) - max_diffmaglim_after_fid_2: 20.673500061035156
# (148) - max_diffmaglim_before_fid_1: nan
# (149) - max_diffmaglim_before_fid_2: 19.746299743652344
# (150) - mean_mag_1: 17.454833984375
# (151) - mean_mag_2: 16.067943572998047
# (152) - median_diffmaglim_after_fid_1: 19.36440086364746
# (153) - median_diffmaglim_after_fid_2: 20.460098266601562
# (154) - median_diffmaglim_before_fid_1: nan
# (155) - median_diffmaglim_before_fid_2: 19.746299743652344
# (156) - min_mag_1: 16.57765769958496
# (157) - min_mag_2: 15.354910850524902
# (158) - n_det_1: 52.0
# (159) - n_det_2: 46.0
# (160) - n_neg_1: 33.0
# (161) - n_neg_2: 29.0
# (162) - n_non_det_after_fid_1: 11.0
# (163) - n_non_det_after_fid_2: 12.0
# (164) - n_non_det_before_fid_1: 0.0
# (165) - n_non_det_before_fid_2: 1.0
# (166) - n_pos_1: 19.0
# (167) - n_pos_2: 17.0
# (168) - positive_fraction_1: 0.36538460850715637
# (169) - positive_fraction_2: 0.3695652186870575
# (170) - rb: 0.8971428871154785
# (171) - sgscore1: 1.0

# %%
### get features per band from an object
obj_name = 'ZTF18abvpirg' # from train
band = 1
features, c, features_names = get_object_features(features_train_ddf, labels_ddf, obj_name, band=band)
fdict = {f:features[kf] for kf,f in enumerate(features_names)}
print(f'obj: {obj_name} - class: {c} features: {len(features)}')
for k,key in enumerate(fdict.keys()):
    print(f'({k}) - {key}: {fdict[key]}')
# Out:
# obj: ZTF18abvpirg - class: Ceph features: 78
# (0) - Amplitude_1: 1.0310996770858765
# (1) - AndersonDarling_1: 0.9999358654022217
# (2) - Autocor_length_1: 4.0
# (3) - Beyond1Std_1: 0.3461538553237915
# (4) - Con_1: 0.0
# (5) - Eta_e_1: 0.010806181468069553
# (6) - ExcessVar_1: 0.0012663761153817177
# (7) - GP_DRW_sigma_1: 0.20221443474292755
# (8) - GP_DRW_tau_1: 60.67272186279297
# (9) - Gskew_1: 0.21646809577941895
# (10) - Harmonics_mag_1_1: 0.6572859883308411
# (11) - Harmonics_mag_2_1: 0.06727560609579086
# (12) - Harmonics_mag_3_1: 0.1119856908917427
# (13) - Harmonics_mag_4_1: 0.12274118512868881
# (14) - Harmonics_mag_5_1: 0.057103462517261505
# (15) - Harmonics_mag_6_1: 0.06308390200138092
# (16) - Harmonics_mag_7_1: 0.005024974700063467
# (17) - Harmonics_mse_1: 0.0406515970826149
# (18) - Harmonics_phase_2_1: 2.0009756088256836
# (19) - Harmonics_phase_3_1: 6.043892860412598
# (20) - Harmonics_phase_4_1: 6.1681036949157715
# (21) - Harmonics_phase_5_1: 1.801235556602478
# (22) - Harmonics_phase_6_1: 2.4778904914855957
# (23) - Harmonics_phase_7_1: 0.04875669628381729
# (24) - IAR_phi_1: 0.991150438785553
# (25) - LinearTrend_1: 0.0013732707593590021
# (26) - MHPS_PN_flag_1: 0.0
# (27) - MHPS_high_1: 0.007308231666684151
# (28) - MHPS_low_1: 11.7152738571167
# (29) - MHPS_non_zero_1: 42.0
# (30) - MHPS_ratio_1: 1603.0242919921875
# (31) - MaxSlope_1: 0.6155768036842346
# (32) - Mean_1: 17.454833984375
# (33) - Meanvariance_1: 0.035897184163331985
# (34) - MedianAbsDev_1: 0.5407611727714539
# (35) - MedianBRP_1: 0.2884615361690521
# (36) - PairSlopeTrend_1: 0.10000000149011612
# (37) - PercentAmplitude_1: 0.06758933514356613
# (38) - Period_band_1: 120.48186492919922
# (39) - Psi_CS_1: 0.345560222864151
# (40) - Psi_eta_1: 0.20559142529964447
# (41) - Pvar_1: 1.0
# (42) - Q31_1: 1.1266120672225952
# (43) - Rcs_1: 0.345560222864151
# (44) - SF_ML_amplitude_1: 1.3339520692825317
# (45) - SF_ML_gamma_1: 0.4822067320346832
# (46) - SPM_A_1: 0.44269534945487976
# (47) - SPM_beta_1: 0.15157769620418549
# (48) - SPM_chi_1: 56.96652603149414
# (49) - SPM_gamma_1: 85.20677185058594
# (50) - SPM_t0_1: 48.18293762207031
# (51) - SPM_tau_fall_1: 99.99945831298828
# (52) - SPM_tau_rise_1: 70.36084747314453
# (53) - Skew_1: 0.16314253211021423
# (54) - SmallKurtosis_1: -0.9578419923782349
# (55) - Std_1: 0.6265794634819031
# (56) - StetsonK_1: 0.9490160942077637
# (57) - delta_mag_fid_1: 2.127901077270508
# (58) - delta_mjd_fid_1: 733.063720703125
# (59) - delta_period_1: 0.0
# (60) - dmag_first_det_fid_1: nan
# (61) - dmag_non_det_fid_1: nan
# (62) - first_mag_1: 17.47696304321289
# (63) - iqr_1: 1.1266120672225952
# (64) - last_diffmaglim_before_fid_1: nan
# (65) - last_mjd_before_fid_1: nan
# (66) - max_diffmaglim_after_fid_1: 20.399099349975586
# (67) - max_diffmaglim_before_fid_1: nan
# (68) - mean_mag_1: 17.454833984375
# (69) - median_diffmaglim_after_fid_1: 19.36440086364746
# (70) - median_diffmaglim_before_fid_1: nan
# (71) - min_mag_1: 16.57765769958496
# (72) - n_det_1: 52.0
# (73) - n_neg_1: 33.0
# (74) - n_non_det_after_fid_1: 11.0
# (75) - n_non_det_before_fid_1: 0.0
# (76) - n_pos_1: 19.0
# (77) - positive_fraction_1: 0.36538460850715637

# %%
# %load_ext autoreload
# %autoreload 2
from mismatch import C_
from mismatch.utils import get_object_features
from dask import dataframe as dd

### get features non-band-wise features
obj_name = 'ZTF18abvpirg' # from train
band = -1
features, c, features_names = get_object_features(features_train_ddf, labels_ddf, obj_name, band=band)
fdict = {f:features[kf] for kf,f in enumerate(features_names)}
print(f'obj: {obj_name} - class: {c} features: {len(features)}')
for k,key in enumerate(fdict.keys()):
    print(f'({k}) - {key}: {fdict[key]}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# obj: ZTF18abvpirg - class: Ceph features: 15
# (0) - Multiband_period: 120.48186492919922
# (1) - Period_fit: 0.14047516882419586
# (2) - Power_rate_1/2: 0.017695672810077667
# (3) - Power_rate_1/3: 0.010019431822001934
# (4) - Power_rate_1/4: 0.00591428903862834
# (5) - Power_rate_3: 0.0020129734184592962
# (6) - Power_rate_4: 0.008709192276000977
# (7) - g-r_max: 1.3278560638427734
# (8) - g-r_max_corr: 1.2227473258972168
# (9) - g-r_mean: 1.164468765258789
# (10) - g-r_mean_corr: 1.3868906497955322
# (11) - gal_b: -63.463775634765625
# (12) - gal_l: 70.93750762939453
# (13) - rb: 0.8971428871154785
# (14) - sgscore1: 1.0

# %%
### get features from a non-labeled sample. returned class is None
obj_name = 'ZTF17aaacvqh' # from test
features, c, features_names = get_object_features(features_test_ddf, labels_ddf, obj_name, band=1)
fdict = {f:features[kf] for kf,f in enumerate(features_names)}
print(f'obj: {obj_name} - class: {c} features: {len(features)}')
for k,key in enumerate(fdict.keys()):
    print(f'({k}) - {key}: {fdict[key]}')
# Out:
# obj: ZTF17aaacvqh - class: None features: 78
# (0) - Amplitude_1: 0.20804178714752197
# (1) - AndersonDarling_1: 1.0
# (2) - Autocor_length_1: 1.0
# (3) - Beyond1Std_1: 0.523809552192688
# (4) - Con_1: 0.0
# (5) - Eta_e_1: 0.9310294389724731
# (6) - ExcessVar_1: 7.536393968621269e-05
# (7) - GP_DRW_sigma_1: 0.019762510433793068
# (8) - GP_DRW_tau_1: 2.9604222774505615
# (9) - Gskew_1: -0.24195298552513123
# (10) - Harmonics_mag_1_1: 0.5847174525260925
# (11) - Harmonics_mag_2_1: 0.44293659925460815
# (12) - Harmonics_mag_3_1: 0.41101929545402527
# (13) - Harmonics_mag_4_1: 0.25584784150123596
# (14) - Harmonics_mag_5_1: 0.1591656357049942
# (15) - Harmonics_mag_6_1: 0.132536381483078
# (16) - Harmonics_mag_7_1: 0.05543297901749611
# (17) - Harmonics_mse_1: 0.00043336168164387345
# (18) - Harmonics_phase_2_1: 3.989422559738159
# (19) - Harmonics_phase_3_1: 1.1418135166168213
# (20) - Harmonics_phase_4_1: 4.432981014251709
# (21) - Harmonics_phase_5_1: 1.9883027076721191
# (22) - Harmonics_phase_6_1: 5.535276889801025
# (23) - Harmonics_phase_7_1: 2.2313716411590576
# (24) - IAR_phi_1: 0.7042553424835205
# (25) - LinearTrend_1: 0.00023602985311299562
# (26) - MHPS_PN_flag_1: 0.0
# (27) - MHPS_high_1: 0.014604239724576473
# (28) - MHPS_low_1: 0.14619982242584229
# (29) - MHPS_non_zero_1: 32.0
# (30) - MHPS_ratio_1: 10.01077938079834
# (31) - MaxSlope_1: 0.1979953497648239
# (32) - Mean_1: 15.453238487243652
# (33) - Meanvariance_1: 0.008751406334340572
# (34) - MedianAbsDev_1: 0.07479705661535263
# (35) - MedianBRP_1: 0.2142857164144516
# (36) - PairSlopeTrend_1: 0.03333333507180214
# (37) - PercentAmplitude_1: 0.021556634455919266
# (38) - Period_band_1: 0.20729677379131317
# (39) - Psi_CS_1: 0.3552178144454956
# (40) - Psi_eta_1: 0.15861085057258606
# (41) - Pvar_1: 1.0
# (42) - Q31_1: 0.14241982996463776
# (43) - Rcs_1: 0.24491441249847412
# (44) - SF_ML_amplitude_1: 0.22885653376579285
# (45) - SF_ML_gamma_1: 0.10263718664646149
# (46) - SPM_A_1: 0.7913283705711365
# (47) - SPM_beta_1: 0.20223048329353333
# (48) - SPM_chi_1: 77.65357208251953
# (49) - SPM_gamma_1: 99.89637756347656
# (50) - SPM_t0_1: 36.893516540527344
# (51) - SPM_tau_fall_1: 99.81047821044922
# (52) - SPM_tau_rise_1: 92.10504913330078
# (53) - Skew_1: -1.0337013006210327
# (54) - SmallKurtosis_1: 0.13404123485088348
# (55) - Std_1: 0.13523755967617035
# (56) - StetsonK_1: 0.8722720742225647
# (57) - delta_mag_fid_1: 0.4262736439704895
# (58) - delta_mjd_fid_1: 712.953369140625
# (59) - delta_period_1: 0.0
# (60) - dmag_first_det_fid_1: nan
# (61) - dmag_non_det_fid_1: nan
# (62) - first_mag_1: 15.389239311218262
# (63) - iqr_1: 0.14241982996463776
# (64) - last_diffmaglim_before_fid_1: nan
# (65) - last_mjd_before_fid_1: nan
# (66) - max_diffmaglim_after_fid_1: 21.079200744628906
# (67) - max_diffmaglim_before_fid_1: nan
# (68) - mean_mag_1: 15.453238487243652
# (69) - median_diffmaglim_after_fid_1: 20.224449157714844
# (70) - median_diffmaglim_before_fid_1: nan
# (71) - min_mag_1: 15.168901443481445
# (72) - n_det_1: 42.0
# (73) - n_neg_1: 35.0
# (74) - n_non_det_after_fid_1: 88.0
# (75) - n_non_det_before_fid_1: 0.0
# (76) - n_pos_1: 7.0
# (77) - positive_fraction_1: 0.1666666716337204
